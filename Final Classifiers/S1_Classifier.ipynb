# %%
pip install flair # must install flair package if first execution

# %%
from flair.data import Sentence
from flair.models import TextClassifier

classifier = TextClassifier.load('en-sentiment') #English-sentiment model pre-trained with IMDB movie reviews.
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 2019-11-22 02:42:38,608 https://s3.eu-central-1.amazonaws.com/alan-nlp/resources/models-v0.4/classy-imdb-en-rnn-cuda%3A0/imdb-v0.4.pt not found in cache, downloading to /tmp/tmpd4y6sm1q
# 100%|██████████| 1501979561/1501979561 [00:18<00:00, 81068171.44B/s]
# 2019-11-22 02:42:57,397 copying /tmp/tmpd4y6sm1q to cache at /root/.flair/models/imdb-v0.4.pt
# 2019-11-22 02:43:02,773 removing temp file /tmp/tmpd4y6sm1q
# 2019-11-22 02:43:02,977 loading file /root/.flair/models/imdb-v0.4.pt

# %%
import pandas as pd
import numpy as np

# Read in Amazon test data
input_data = pd.read_csv('data/test.csv',low_memory=False)

# Extract text column
test_attr = input_data[['reviewText']]

# Extract label column
test_label = input_data[['overall']]

# %%
# Extract text and label values
X = test_attr.values
Y = test_label.values

# Prepare list of TRUE labels
actual = np.array(test_label)
#actual
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [1],
#        [0],
#        [0]])

# %%
from flair.data import Sentence

predicted = []
pred = []

# make predictions for each review in test set
for review in X:
  s = Sentence(review[0])
  p = classifier.predict(s)
  predicted.append(s.labels[0].value)

# %%
# map 0, 1 values to POS, NEG predictions
pred = list(map(lambda x: 1 if x == "POSITIVE" else 0, predicted))

pred = np.array(pred)
pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# generate and print performance statistics
accuracy = accuracy_score(actual, pred) * 100
precision = precision_score(actual, pred) * 100
recall = recall_score(actual, pred) * 100
f1 = f1_score(actual, pred)

print ('Accuracy is {:.4f}'.format(accuracy))
print('Precision is {:.4f}'.format(precision))
print('Recall is {:.4f}'.format(recall))
print('F1 Score is {:.4f}'.format(f1))
# Out:
# Accuracy is 67.9600
# Precision is 69.6156
# Recall is 63.7400
# F1 Score is 0.6655
