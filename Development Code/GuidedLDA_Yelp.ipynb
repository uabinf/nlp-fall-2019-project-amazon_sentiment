# %% [markdown]
# # **Guided LDA Implementation using Yelp Dataset**

# %%
# !pip install guidedlda
# Out:
# Collecting guidedlda
#   Downloading https://files.pythonhosted.org/packages/f8/ee/6d6e2b3525388399e12a4482554c7529a5fcf5e99c50a60abaa02894b8bf/guidedlda-2.0.0.dev22.tar.gz (2.1MB)
#      |████████████████████████████████| 2.1MB 6.4MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from guidedlda) (1.17.4)
# Building wheels for collected packages: guidedlda
#   Building wheel for guidedlda (setup.py) ... done
#   Created wheel for guidedlda: filename=guidedlda-2.0.0.dev22-cp36-cp36m-linux_x86_64.whl size=2479773 sha256=cb06935209b32f2d53012c7c58d82878f3f52d150352e834fca043c2d6592fa0
#   Stored in directory: /root/.cache/pip/wheels/cf/cb/c4/95897cbe4e2e12bd01db3c5cb004c744d2cfd68ecc692ce39e
# Successfully built guidedlda
# Installing collected packages: guidedlda
# Successfully installed guidedlda-2.0.0.dev22

# %%
import numpy as np
import guidedlda

X = guidedlda.datasets.load_data(guidedlda.datasets.NYT)
vocab = guidedlda.datasets.load_vocab(guidedlda.datasets.NYT)
word2id = dict((v, idx) for idx, v in enumerate(vocab))

# %%
np.shape(X)

# %% [markdown]
# **Create Term Document Matrix**

# %%
pip install textmining
# Out:
# Collecting textmining
#   Downloading https://files.pythonhosted.org/packages/f7/ca/3fb84b7fc0f5e51c4f8d4e6ba5bb5cc833410700bcec22594eefe072febe/textmining-1.0.zip (1.9MB)
#      |████████████████████████████████| 1.9MB 6.6MB/s
# Building wheels for collected packages: textmining
#   Building wheel for textmining (setup.py) ... done
#   Created wheel for textmining: filename=textmining-1.0-cp36-none-any.whl size=1855282 sha256=06636a11883ecdf82ca75d526acde06251e7b4f12acb1dbbdbed0ea74d050e50
#   Stored in directory: /root/.cache/pip/wheels/7a/1f/78/0a67c3d717378ec9d9a840a8d7d2b959796cbf505f388d35ea
# Successfully built textmining
# Installing collected packages: textmining
# Successfully installed textmining-1.0

# %%
import textmining

# Create documents
data = pd.read_csv('yelp_all_header.csv');
data_text = data[['text']]
#data_text['index'] = data_text.index
documents = data_text
  
# Initialize class to create term-document matrix
#tdm = textmining.TermDocumentMatrix()

# Add the documents
#tdm.add_doc(doc1)
#tdm.add_doc(doc2)
#tdm.add_doc(doc3)

# Write out the matrix to a csv file. Note that setting cutoff=1 means
# that words which appear in 1 or more documents will be included in
# the output (i.e. every word will appear in the output). The default
# for cutoff is 2, since we usually aren't interested in words which
# appear in a single document. For this example we want to see all
# words however, hence cutoff=1.
#tdm.write_csv('matrix.csv', cutoff=1)

# Instead of writing out the matrix you can also access its rows directly.
# Let's print them to the screen.
#for row in tdm.rows(cutoff=1):
#        print row

for i in range(1,10):
  print(documents[i])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-10d83417826d> in <module>()
# ----> 1 import textmining
#       2
#       3 # Create documents
#       4 data = pd.read_csv('yelp_all_header.csv');
#       5 data_text = data[['text']]
#
# /usr/local/lib/python3.6/dist-packages/textmining/__init__.py in <module>()
#       1 import re
# ----> 2 import stemmer
#       3 import csv
#       4 import os
#       5
#
# ModuleNotFoundError: No module named 'stemmer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
